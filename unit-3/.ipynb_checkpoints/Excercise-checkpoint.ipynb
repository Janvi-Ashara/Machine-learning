# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model,model_selection
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error

df=pd.read_csv("housing-data.csv")
print(df)
for column in df.columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[column], kde=True)  # kde=True adds a Kernel Density Estimate plot
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
# Out:
#     sqft  bdrms  age   price
# 0   2104      3   70  399900
# 1   1600      3   28  329900
# 2   2400      3   44  369000
# 3   1416      2   49  232000
# 4   3000      4   75  539900
# 5   1985      4   61  299900
# 6   1534      3   12  314900
# 7   1427      3   57  198999
# 8   1380      3   14  212000
# 9   1494      3   15  242500
# 10  1940      4    7  239999
# 11  2000      3   27  347000
# 12  1890      3   45  329999
# 13  4478      5   49  699900
# 14  1268      3   58  259900
# 15  2300      4   77  449900
# 16  1320      2   62  299900
# 17  1236      3   78  199900
# 18  2609      4    5  499998
# 19  3031      4   21  599000
# 20  1767      3   44  252900
# 21  1888      2   79  255000
# 22  1604      3   13  242900
# 23  1962      4   53  259900
# 24  3890      3   36  573900
# 25  1100      3   60  249900
# 26  1458      3   29  464500
# 27  2526      3   13  469000
# 28  2200      3   28  475000
# 29  2637      3   25  299900
# 30  1839      2   40  349900
# ...

# %% [markdown]
# ## load the model linear regression

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error
x=np.array(df[['sqft','bdrms','age']]).reshape(-1,1)
y=np.array(df['price']).reshape(-1,1)
# print(x.head())
# print(y.head())
print(len(x))
print(len(y))
x=x[0:47]

# split the dataset in traning and testing
xtrain,xtest,ytrain,ytest=model_selection.train_test_split(x,y,test_size=0.2)

# load the model
lr=linear_model.LinearRegression()

# train the model
lr.fit(xtrain,ytrain)

# test the model
ytest_predicted=lr.predict(xtest)

# Visualization the model
plt.scatter(xtrain,ytrain,color="red")
plt.scatter(xtest,ytest_predicted,color="blue")
plt.show()
print("mean_absolute_error : " ,mean_absolute_error(ytest,ytest_predicted))
print("mean_squared_error : ",mean_squared_error(ytest,ytest_predicted))
print("mean_percentage_error :",mean_absolute_percentage_error(ytest,ytest_predicted))

# %% [markdown]
# ## Excerise -2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import model_selection,preprocessing

df=pd.read_csv('HR_comma_sep.csv')
print(df.to_string())

# %%
df.head()
# print(df.head(len(df)))  # This will display all rows in the dataframe

# %%
df.info()

# %%
df.describe()

# %%
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv('HR_comma_sep.csv')
# print(df.to_string())
x=df[['satisfaction_level','last_evaluation','number_project','average_montly_hours','time_spend_company','Work_accident','left','promotion_last_5years']] 
y=df[['sales','salary']]

print("=======================    x     ===============================")
# print(x)
scaller_model=preprocessing.MinMaxScaler()
op1 = scaller_model.fit(x)
op2= op1.transform(x)

print("====================  min max scaler ========================")
# print(op2)
print("======================   y    ===========================")
# print(y)
# label_data=preprocessing.LabelEncoder
# op=np.array(label_data.fit_transform(df.sales,df.salary)).reshape(-1,1)
label_encoder = LabelEncoder()
df['sales_encoded'] = label_encoder.fit_transform(df['sales'])
df['salary_encoded'] = label_encoder.fit_transform(df['salary'])
print("===================        label encoding ========================")
# print(op)
print("================================================================")
# assume 'df' is your DataFrame and 'column_name' is the categorical feature
dummy_cols = pd.get_dummies(df['sales'])
print(dummy_cols)
# assume 'df_num' is your DataFrame with numerical features

# combined_df = pd.concat([satisfaction_level, dummy_cols], axis=1)
# combined_df = pd.concat([df_num['satisfaction_level'], dummy_cols], axis=1)  # concatenate only satisfaction_level column
# combined_df = pd.concat([df_num['satisfaction_level'], dummy_cols], axis=1)  # concatenate only satisfaction_level column
# df_num = df[['satisfaction_level', 'other_numerical_columns']]  # replace 'other_numerical_columns' with your actual column names
combined_df = pd.concat([df_num['satisfaction_level'], dummy_cols], axis=1)
xtrain,ytrain,xtest,ytest=model_selection.train_test_split(op2,op,test_size=0.3)
